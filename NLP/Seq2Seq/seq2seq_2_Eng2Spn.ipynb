# %%
from __future__ import print_function, division
from builtins import range, input
# Note: you may need to update your version of future
# sudo pip install -U future

import os, sys

from keras.models import Model
from keras.layers import Input, LSTM, GRU, Dense, Embedding
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
import numpy as np
import matplotlib.pyplot as plt

import keras.backend as K
if len(K.tensorflow_backend._get_available_gpus()) > 0:
    from keras.layers import CuDNNLSTM as LSTM
    from keras.layers import CuDNNGRU as GRU
# Out:
# Using TensorFlow backend.

# %%
# some config
BATCH_SIZE = 64  # Batch size for training.
EPOCHS = 40  # Number of epochs to train for.
LATENT_DIM = 256  # Latent dimensionality of the encoding space.
NUM_SAMPLES = 10000  # Number of samples to train on.
MAX_NUM_WORDS = 20000
EMBEDDING_DIM = 100

# Where we will store the data
input_texts = [] # sentence in original language
target_texts = [] # sentence in target language
target_texts_inputs = [] # sentence in target language offset by 1

# %%
# load in the data
# download the data at: http://www.manythings.org/anki/
t = 0
for line in open('spa.txt'):
#     print(line)
  # only keep a limited number of samples
    t += 1
    if t > NUM_SAMPLES:
        break

    # input and target are separated by tab
    if '\t' not in line:
        continue

    # split up the input and translation
    input_text, translation = line.rstrip().split('\t')[0], line.rstrip().split('\t')[1]

    # make the target input and output
    # recall we'll be using teacher forcing
    target_text = translation + ' <eos>'
    target_text_input = '<sos> ' + translation

    input_texts.append(input_text)
    target_texts.append(target_text)
    target_texts_inputs.append(target_text_input)
    
print("num samples:", len(input_texts))
# Out:
# Go.	Ve.	CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #4986655 (cueyayotl)
#
# Go.	Vete.	CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #4986656 (cueyayotl)
#
# Go.	Vaya.	CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #4986657 (cueyayotl)
#
# Go.	V찼yase.	CC-BY 2.0 (France) Attribution: tatoeba.org #2877272 (CM) & #6586271 (arh)
#
# Hi.	Hola.	CC-BY 2.0 (France) Attribution: tatoeba.org #538123 (CM) & #431975 (Leono)
#
# Run!	징Corre!	CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #1685404 (Elenitigormiti)
#
# Run!	징Corran!	CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #5213896 (cueyayotl)
#
# Run!	징Corra!	CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #8005613 (Seael)
#
# Run!	징Corred!	CC-BY 2.0 (France) Attribution: tatoeba.org #906328 (papabear) & #8005615 (Seael)
#
# Run.	Corred.	CC-BY 2.0 (France) Attribution: tatoeba.org #4008918 (JSakuragi) & #6681472 (arh)
#
# Who?	쩔Qui챕n?	CC-BY 2.0 (France) Attribution: tatoeba.org #2083030 (CK) & #2122720 (Shishir)
#
# Wow!	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #52027 (Zifre) & #4726230 (cueyayotl)
#
# Fire!	징Fuego!	CC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #1832096 (Shishir)
#
# Fire!	징Incendio!	CC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #3112459 (marcelostockle)
#
# Fire!	징Disparad!	CC-BY 2.0 (France) Attribution: tatoeba.org #1829639 (Spamster) & #3112460 (marcelostockle)
#
# Help!	징Ayuda!	CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #927374 (mrc3306)
#
# Help!	징Socorro! 징Auxilio!	CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #1216469 (wallebot)
#
# Help!	징Auxilio!	CC-BY 2.0 (France) Attribution: tatoeba.org #435084 (lukaszpp) & #1343034 (marcelostockle)
#
# Jump!	징Salta!	CC-BY 2.0 (France) Attribution: tatoeba.org #1102981 (jamessilver) & #1503535 (marcelostockle)
#
# Jump.	Salte.	CC-BY 2.0 (France) Attribution: tatoeba.org #631038 (Shishir) & #607995 (arashi_29)
#
# Stop!	징Parad!	CC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #4347076 (saverius)
#
# Stop!	징Para!	CC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #5669421 (cueyayotl)
#
# Stop!	징Pare!	CC-BY 2.0 (France) Attribution: tatoeba.org #448320 (FeuDRenais) & #5669422 (cueyayotl)
#
# Wait!	징Espera!	CC-BY 2.0 (France) Attribution: tatoeba.org #1744314 (belgavox) & #2122717 (Shishir)
#
# Wait.	Esperen.	CC-BY 2.0 (France) Attribution: tatoeba.org #3048304 (camilozeta) & #3048255 (hayastan)
#
# Go on.	Contin첬a.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #4940109 (Francisco_M)
#
# Go on.	Contin첬e.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230774 (CK) & #4940116 (Francisco_M)
#
# Hello!	Hola.	CC-BY 2.0 (France) Attribution: tatoeba.org #373330 (CK) & #431975 (Leono)
#
# I hid.	Me ocult챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397686 (CK) & #8410504 (arh)
#
# I hid.	Me escond챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397686 (CK) & #8410506 (arh)
#
# I hid.	Me ocultaba.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397686 (CK) & #8410532 (arh)
#
# I hid.	Me escond챠a.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397686 (CK) & #8410533 (arh)
#
# I ran.	Corr챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828607 (CK) & #6682393 (arh)
#
# I ran.	Corr챠a.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828607 (CK) & #6682394 (arh)
#
# I try.	Lo intento.	CC-BY 2.0 (France) Attribution: tatoeba.org #20776 (CK) & #1449864 (nullsoul9)
#
# I won!	징He ganado!	CC-BY 2.0 (France) Attribution: tatoeba.org #2005192 (CK) & #2351590 (Shishir)
#
# Oh no!	징Oh, no!	CC-BY 2.0 (France) Attribution: tatoeba.org #1299275 (CK) & #5056288 (don_ramon)
#
# Relax.	Tom찼telo con soda.	CC-BY 2.0 (France) Attribution: tatoeba.org #1722133 (shanghainese) & #5124533 (ecorralest101)
#
# Shoot!	징Fuego!	CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #1832096 (Shishir)
#
# Shoot!	징Disparad!	CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #3112460 (marcelostockle)
#
# Shoot!	징Disparen!	CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #3285306 (cueyayotl)
#
# Shoot!	징Dispara!	CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #7936886 (Seael)
#
# Shoot!	징Dispar찼!	CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #7936887 (Seael)
#
# Shoot!	징Dispare!	CC-BY 2.0 (France) Attribution: tatoeba.org #7422159 (CM) & #7936888 (Seael)
#
# Smile.	Sonr챠e.	CC-BY 2.0 (France) Attribution: tatoeba.org #2764108 (CK) & #1852302 (Shishir)
#
# Attack!	징Al ataque!	CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #4554129 (swyter)
#
# Attack!	징Atacad!	CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #4554130 (swyter)
#
# Attack!	징Ataque!	CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #8005608 (Seael)
#
# Attack!	징Ataquen!	CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #8005609 (Seael)
#
# Attack!	징Ataca!	CC-BY 2.0 (France) Attribution: tatoeba.org #1972610 (CK) & #8005610 (Seael)
#
# Get up.	Levanta.	CC-BY 2.0 (France) Attribution: tatoeba.org #896158 (pauldhunt) & #5769212 (arh)
#
# Go now.	Ve ahora mismo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #5165878 (cueyayotl)
#
# Go now.	Id ahora mismo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #8005616 (Seael)
#
# Go now.	Vaya ahora mismo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #8005617 (Seael)
#
# Go now.	Vayan ahora mismo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #8005618 (Seael)
#
# Go now.	Ve ya.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #8005619 (Seael)
#
# Go now.	Id ya.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #8005621 (Seael)
#
# Go now.	Vaya ya.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #8005622 (Seael)
#
# Go now.	Vayan ya.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230771 (CK) & #8005623 (Seael)
#
# Got it!	징Lo tengo!	CC-BY 2.0 (France) Attribution: tatoeba.org #320484 (CM) & #1357534 (marcelostockle)
#
# Got it?	쩔Lo pillas?	CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #536562 (Shishir)
#
# Got it?	쩔Entendiste?	CC-BY 2.0 (France) Attribution: tatoeba.org #455353 (FeuDRenais) & #989540 (hayastan)
#
# He ran.	횋l corri처.	CC-BY 2.0 (France) Attribution: tatoeba.org #672229 (CK) & #1426322 (marcelostockle)
#
# Hop in.	M챕tete adentro.	CC-BY 2.0 (France) Attribution: tatoeba.org #1111548 (Scott) & #1336569 (marcelostockle)
#
# Hug me.	Abr찼zame.	CC-BY 2.0 (France) Attribution: tatoeba.org #1852504 (CK) & #5769213 (arh)
#
# I care.	Me preocupo.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397687 (CK) & #8410507 (arh)
#
# I fell.	Me ca챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #3824714 (CK) & #5559530 (ecorralest101)
#
# I fled.	Hu챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397688 (CK) & #8410508 (arh)
#
# I fled.	Me escap챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397688 (CK) & #8410509 (arh)
#
# I fled.	Hu챠a.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397688 (CK) & #8410534 (arh)
#
# I fled.	Me escapaba.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397688 (CK) & #8410535 (arh)
#
# I know.	Yo lo s챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #319990 (CK) & #1672856 (Shishir)
#
# I left.	Sal챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #2307509 (erikspen) & #630772 (Leono)
#
# I lied.	Ment챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #3935374 (gianich73) & #3935240 (gianich73)
#
# I lost.	Perd챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #1755073 (Eldad) & #4526799 (cueyayotl)
#
# I quit.	Dimito.	CC-BY 2.0 (France) Attribution: tatoeba.org #731636 (Eldad) & #731631 (Shishir)
#
# I quit.	Renunci챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #731636 (Eldad) & #4314875 (pchamorro)
#
# I quit.	Lo dejo.	CC-BY 2.0 (France) Attribution: tatoeba.org #731636 (Eldad) & #7578166 (arh)
#
# I sang.	Cant챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #7290637 (shekitten) & #5016766 (don_ramon)
#
# I wept.	Llor챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397690 (CK) & #8410510 (arh)
#
# I wept.	Lloraba.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397690 (CK) & #8410511 (arh)
#
# I work.	Estoy trabajando.	CC-BY 2.0 (France) Attribution: tatoeba.org #1581080 (olgalu) & #2150085 (hayastan)
#
# I'm 19.	Tengo diecinueve.	CC-BY 2.0 (France) Attribution: tatoeba.org #442400 (sacredceltic) & #5769211 (arh)
#
# I'm up.	Estoy levantado.	CC-BY 2.0 (France) Attribution: tatoeba.org #2765357 (arnxy20) & #5769214 (arh)
#
# Listen.	Escucha.	CC-BY 2.0 (France) Attribution: tatoeba.org #1913088 (CK) & #2850907 (cueyayotl)
#
# Listen.	Escuche.	CC-BY 2.0 (France) Attribution: tatoeba.org #1913088 (CK) & #2850908 (cueyayotl)
#
# Listen.	Escuchen.	CC-BY 2.0 (France) Attribution: tatoeba.org #1913088 (CK) & #2850911 (cueyayotl)
#
# No way!	징No puede ser!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #2704 (Shishir)
#
# No way!	De ninguna manera.	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #545574 (Shishir)
#
# No way!	징De ninguna manera!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #728909 (ventana)
#
# No way!	징Imposible!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #1192105 (marcelostockle)
#
# No way!	징De ning첬n modo!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #1686530 (Shishir)
#
# No way!	징De eso nada!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #1686532 (Shishir)
#
# No way!	징Ni cagando!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #3792208 (cueyayotl)
#
# No way!	징Mangos!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #3843189 (cueyayotl)
#
# No way!	징Minga!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #3843192 (cueyayotl)
#
# No way!	징Ni en pedo!	CC-BY 2.0 (France) Attribution: tatoeba.org #2175 (CS) & #5124593 (don_ramon)
#
# Really?	쩔En serio?	CC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #344138 (tatoerique)
#
# Really?	쩔La verdad?	CC-BY 2.0 (France) Attribution: tatoeba.org #373216 (kotobaboke) & #5018755 (don_ramon)
#
# Thanks.	징Gracias!	CC-BY 2.0 (France) Attribution: tatoeba.org #2057650 (nava) & #382058 (hayastan)
#
# Thanks.	Gracias.	CC-BY 2.0 (France) Attribution: tatoeba.org #2057650 (nava) & #3594305 (carenas)
#
# Try it.	Pru챕balo.	CC-BY 2.0 (France) Attribution: tatoeba.org #4756252 (cairnhead) & #4748670 (ecorralest101)
#
# We try.	Lo procuramos.	CC-BY 2.0 (France) Attribution: tatoeba.org #247763 (CK) & #5769210 (arh)
#
# We won.	Ganamos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2107675 (CK) & #5047998 (don_ramon)
#
# Why me?	쩔Por qu챕 yo?	CC-BY 2.0 (France) Attribution: tatoeba.org #24958 (CK) & #720463 (Shishir)
#
# Ask Tom.	Preg첬ntale a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954263 (CK) & #1998766 (Shishir)
#
# Awesome!	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #433512 (CK) & #4726230 (cueyayotl)
#
# Be calm.	Mantente en calma.	CC-BY 2.0 (France) Attribution: tatoeba.org #1916317 (CK) & #5769225 (arh)
#
# Be cool.	Estate tranquilo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1860752 (CK) & #5769222 (arh)
#
# Be fair.	S챕 justo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1916316 (CK) & #5707785 (arh)
#
# Be good.	S챕 bueno.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932304 (Seael) & #7842061 (arh)
#
# Be good.	S챕 buena.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932304 (Seael) & #7932307 (Seael)
#
# Be good.	Sed buenas.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932304 (Seael) & #7932308 (Seael)
#
# Be good.	Sed buenos.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932304 (Seael) & #7932309 (Seael)
#
# Be good.	Sea buena.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932304 (Seael) & #7932310 (Seael)
#
# Be good.	Sea bueno.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932304 (Seael) & #7932311 (Seael)
#
# Be good.	Sean buenas.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932304 (Seael) & #7932313 (Seael)
#
# Be good.	Sean buenos.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932304 (Seael) & #7932315 (Seael)
#
# Be kind.	Sean gentiles.	CC-BY 2.0 (France) Attribution: tatoeba.org #1916315 (CK) & #2092229 (hayastan)
#
# Be nice.	S챕 agradable.	CC-BY 2.0 (France) Attribution: tatoeba.org #1916314 (CK) & #5769224 (arh)
#
# Beat it.	P챠rate.	CC-BY 2.0 (France) Attribution: tatoeba.org #37902 (CM) & #5769215 (arh)
#
# Call me.	Llamame.	CC-BY 2.0 (France) Attribution: tatoeba.org #1553532 (CK) & #1555788 (hayastan)
#
# Call me.	Llamadme.	CC-BY 2.0 (France) Attribution: tatoeba.org #1553532 (CK) & #1748231 (Shishir)
#
# Call me.	Ll찼mame.	CC-BY 2.0 (France) Attribution: tatoeba.org #1553532 (CK) & #1748232 (Shishir)
#
# Call us.	Ll찼manos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1916313 (CK) & #2351591 (Shishir)
#
# Come in.	Entre.	CC-BY 2.0 (France) Attribution: tatoeba.org #348091 (Hertz) & #1501220 (marcelostockle)
#
# Come in.	Pase.	CC-BY 2.0 (France) Attribution: tatoeba.org #348091 (Hertz) & #1501221 (marcelostockle)
#
# Come in.	징Entren!	CC-BY 2.0 (France) Attribution: tatoeba.org #348091 (Hertz) & #2077279 (cueyayotl)
#
# Come on!	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #24697 (CK) & #4726230 (cueyayotl)
#
# Come on.	횁ndale.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954266 (CK) & #3442057 (cueyayotl)
#
# Come on.	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #1954266 (CK) & #4726230 (cueyayotl)
#
# Drop it!	Su챕ltalo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1972621 (CK) & #5259208 (Omnivoro)
#
# Get Tom.	Agarra a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #1972633 (CK) & #4527533 (cueyayotl)
#
# Get out!	B찼jate.	CC-BY 2.0 (France) Attribution: tatoeba.org #266790 (CK) & #5769216 (arh)
#
# Get out.	Salte.	CC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #607995 (arashi_29)
#
# Get out.	Sal.	CC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #630770 (Leono)
#
# Get out.	Sal챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #630772 (Leono)
#
# Get out.	Salid.	CC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #630776 (Leono)
#
# Get out.	Salgan.	CC-BY 2.0 (France) Attribution: tatoeba.org #22016 (Eldad) & #630777 (Leono)
#
# Go away!	징Vete de aqu챠!	CC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #870324 (washisnein)
#
# Go away!	징L찼rgate!	CC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #877248 (Shishir)
#
# Go away!	징Salga de aqu챠!	CC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #994731 (hayastan)
#
# Go away!	징Largo!	CC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #1266359 (wallebot)
#
# Go away!	징Vete ya!	CC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #1266363 (wallebot)
#
# Go away!	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #4726230 (cueyayotl)
#
# Go away!	징A la calle!	CC-BY 2.0 (France) Attribution: tatoeba.org #433518 (CK) & #5101735 (ecorralest101)
#
# Go away.	징Vete de aqu챠!	CC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #870324 (washisnein)
#
# Go away.	징L찼rgate!	CC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #877248 (Shishir)
#
# Go away.	징Largo!	CC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #1266359 (wallebot)
#
# Go away.	징Vete ya!	CC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #1266363 (wallebot)
#
# Go away.	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #4726230 (cueyayotl)
#
# Go away.	L찼rguese.	CC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #5165644 (cueyayotl)
#
# Go away.	V찼yase.	CC-BY 2.0 (France) Attribution: tatoeba.org #433491 (CK) & #6586271 (arh)
#
# Go home.	Vete a casa.	CC-BY 2.0 (France) Attribution: tatoeba.org #2230769 (CK) & #1841889 (marcelostockle)
#
# Go slow.	Vaya despacio.	CC-BY 2.0 (France) Attribution: tatoeba.org #2254627 (_undertoad) & #2254628 (hayastan)
#
# Goodbye!	징Hasta luego!	CC-BY 2.0 (France) Attribution: tatoeba.org #516745 (minshirui) & #427036 (hayastan)
#
# Goodbye!	Hasta la vista.	CC-BY 2.0 (France) Attribution: tatoeba.org #516745 (minshirui) & #562079 (Shishir)
#
# Goodbye!	징Chau!	CC-BY 2.0 (France) Attribution: tatoeba.org #516745 (minshirui) & #995315 (colonqn)
#
# Hang on!	징Espera!	CC-BY 2.0 (France) Attribution: tatoeba.org #1894404 (Spamster) & #2122717 (Shishir)
#
# Hang on!	징Espera un momento!	CC-BY 2.0 (France) Attribution: tatoeba.org #1894404 (Spamster) & #4557188 (swyter)
#
# Hang on!	징Un segundo!	CC-BY 2.0 (France) Attribution: tatoeba.org #1894404 (Spamster) & #4557189 (swyter)
#
# Hang on.	Agarra fuertemente.	CC-BY 2.0 (France) Attribution: tatoeba.org #1972640 (CK) & #4940279 (Francisco_M)
#
# He came.	횋l vino.	CC-BY 2.0 (France) Attribution: tatoeba.org #853153 (piksea) & #853498 (japegon)
#
# He quit.	횋l renunci처.	CC-BY 2.0 (France) Attribution: tatoeba.org #1580339 (sam_m) & #1099417 (Shishir)
#
# Help me!	Ay첬dame.	CC-BY 2.0 (France) Attribution: tatoeba.org #1126684 (CK) & #515909 (Shishir)
#
# Help me.	Ay첬dame.	CC-BY 2.0 (France) Attribution: tatoeba.org #266065 (Zifre) & #515909 (Shishir)
#
# Help me.	횋chame una mano.	CC-BY 2.0 (France) Attribution: tatoeba.org #266065 (Zifre) & #566549 (Shishir)
#
# Help me.	Ayudame.	CC-BY 2.0 (France) Attribution: tatoeba.org #266065 (Zifre) & #5054307 (don_ramon)
#
# Help us.	Ay첬danos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2187193 (CK) & #2794287 (marcelostockle)
#
# Hi, Tom.	징Hola, Tom!	CC-BY 2.0 (France) Attribution: tatoeba.org #2549834 (CK) & #4527517 (cueyayotl)
#
# Hit Tom.	Golpea a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203859 (CK) & #5707782 (arh)
#
# Hold it!	Espera.	CC-BY 2.0 (France) Attribution: tatoeba.org #280203 (CK) & #3273993 (Shishir)
#
# Hold it.	Sostenlo.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932268 (Seael) & #7860122 (arh)
#
# Hold it.	Sostenedlo.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932268 (Seael) & #7932269 (Seael)
#
# Hold it.	Sost챕ngalo.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932268 (Seael) & #7932271 (Seael)
#
# Hold it.	Sost챕nganlo.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932268 (Seael) & #7932272 (Seael)
#
# Hold it.	Sost챕nganla.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932268 (Seael) & #7932273 (Seael)
#
# Hold it.	Sost챕ngala.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932268 (Seael) & #7932274 (Seael)
#
# Hold it.	Sostenla.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932268 (Seael) & #7932275 (Seael)
#
# Hold it.	Sostenedla.	CC-BY 2.0 (France) Attribution: tatoeba.org #7932268 (Seael) & #7932276 (Seael)
#
# Hold on.	Resista.	CC-BY 2.0 (France) Attribution: tatoeba.org #1357000 (sacredceltic) & #4940211 (Francisco_M)
#
# Hold on.	Resiste.	CC-BY 2.0 (France) Attribution: tatoeba.org #1357000 (sacredceltic) & #4940221 (Francisco_M)
#
# Hold on.	Agarra fuertemente.	CC-BY 2.0 (France) Attribution: tatoeba.org #1357000 (sacredceltic) & #4940279 (Francisco_M)
#
# Hug Tom.	Abraza a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203860 (CK) & #5147457 (Kary)
#
# I agree.	Estoy de acuerdo.	CC-BY 2.0 (France) Attribution: tatoeba.org #436281 (lukaszpp) & #378279 (hayastan)
#
# I agree.	De acuerdo.	CC-BY 2.0 (France) Attribution: tatoeba.org #436281 (lukaszpp) & #803643 (Munia)
#
# I bowed.	Me inclin챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828612 (CK) & #5834164 (albrusgher)
#
# I fired.	Dispar챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397691 (CK) & #8410512 (arh)
#
# I froze.	Me congel챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397692 (CK) & #8410515 (arh)
#
# I froze.	Me hel챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397692 (CK) & #8410516 (arh)
#
# I froze.	Me qued챕 quieto.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397692 (CK) & #8410517 (arh)
#
# I moved.	Me he mudado.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828617 (CK) & #6686443 (arh)
#
# I moved.	Me mud챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828617 (CK) & #6686444 (arh)
#
# I moved.	Me traslad챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828617 (CK) & #6686445 (arh)
#
# I moved.	Me he trasladado.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828617 (CK) & #6686447 (arh)
#
# I slept.	Dorm챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #3199633 (CM) & #4632541 (cueyayotl)
#
# I tried.	Lo intent챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #2283721 (CK) & #4557692 (swyter)
#
# I'll go.	Ir챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #1174876 (CK) & #5769218 (arh)
#
# I'm Tom.	Soy Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2283732 (CK) & #3188898 (Shishir)
#
# I'm fat.	Estoy gordo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1120816 (cntrational) & #1143590 (Shishir)
#
# I'm fat.	Soy gorda.	CC-BY 2.0 (France) Attribution: tatoeba.org #1120816 (cntrational) & #2906826 (hayastan)
#
# I'm fit.	Estoy en forma.	CC-BY 2.0 (France) Attribution: tatoeba.org #3330525 (CK) & #5769230 (arh)
#
# I'm hit!	Estoy afectado.	CC-BY 2.0 (France) Attribution: tatoeba.org #1829472 (Spamster) & #5769220 (arh)
#
# I'm old.	Soy viejo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1924560 (Zaghawa) & #5769226 (arh)
#
# I'm shy.	Soy t챠mido.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203346 (CK) & #4935767 (Ruthdq)
#
# I'm wet.	Estoy mojada.	CC-BY 2.0 (France) Attribution: tatoeba.org #1780075 (Spamster) & #1781618 (hayastan)
#
# It's OK.	Est찼 bien.	CC-BY 2.0 (France) Attribution: tatoeba.org #413756 (CK) & #1372070 (marcelostockle)
#
# It's me!	Soy yo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1349952 (sacredceltic) & #503555 (Shishir)
#
# It's me.	Soy yo.	CC-BY 2.0 (France) Attribution: tatoeba.org #42400 (sysko) & #503555 (Shishir)
#
# Join us.	횣nete a nosotros.	CC-BY 2.0 (France) Attribution: tatoeba.org #1745546 (belgavox) & #2013757 (leoruilova)
#
# Join us.	S챕 parte nuestra.	CC-BY 2.0 (France) Attribution: tatoeba.org #1745546 (belgavox) & #2013758 (leoruilova)
#
# Keep it.	Gu찼rdalo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1913087 (CK) & #4482016 (cueyayotl)
#
# Lie low.	Pasa desapercibido.	CC-BY 2.0 (France) Attribution: tatoeba.org #7966956 (CK) & #8410496 (arh)
#
# Me, too.	Yo, tambi챕n.	CC-BY 2.0 (France) Attribution: tatoeba.org #321985 (CK) & #5769217 (arh)
#
# Open up.	Abre.	CC-BY 2.0 (France) Attribution: tatoeba.org #22061 (CM) & #1443710 (marcelostockle)
#
# Perfect!	징Perfecto!	CC-BY 2.0 (France) Attribution: tatoeba.org #374568 (blay_paul) & #578818 (Shishir)
#
# Push it.	Emp첬jala.	CC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #7603480 (arh)
#
# Push it.	Emp첬jalo.	CC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #7932243 (Seael)
#
# Push it.	Emp첬jadlo.	CC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #7932244 (Seael)
#
# Push it.	Emp첬jadla.	CC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #7932245 (Seael)
#
# Push it.	Emp첬jelo.	CC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #7932247 (Seael)
#
# Push it.	Emp첬jela.	CC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #7932248 (Seael)
#
# Push it.	Emp첬jenlo.	CC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #7932249 (Seael)
#
# Push it.	Emp첬jenla.	CC-BY 2.0 (France) Attribution: tatoeba.org #6049385 (mailohilohi) & #7932250 (Seael)
#
# See you.	Nos vemos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1151432 (Roggy) & #1302968 (leoruilova)
#
# Show me.	Mu챕stramelo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1972649 (CK) & #2352589 (Shishir)
#
# Show me.	Ens챕챰amelo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1972649 (CK) & #4557210 (swyter)
#
# Show me.	Mostrame.	CC-BY 2.0 (France) Attribution: tatoeba.org #1972649 (CK) & #5040892 (don_ramon)
#
# Shut up!	징Cierra la boca!	CC-BY 2.0 (France) Attribution: tatoeba.org #462430 (lukaszpp) & #535343 (Shishir)
#
# Shut up!	징Cerr찼 el pico!	CC-BY 2.0 (France) Attribution: tatoeba.org #462430 (lukaszpp) & #5118397 (don_ramon)
#
# Skip it.	S찼ltatelo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1953076 (ozzie) & #4557194 (swyter)
#
# So long.	Hasta la vista.	CC-BY 2.0 (France) Attribution: tatoeba.org #2267731 (_undertoad) & #562079 (Shishir)
#
# So long.	Hasta luego.	CC-BY 2.0 (France) Attribution: tatoeba.org #2267731 (_undertoad) & #2267734 (cueyayotl)
#
# Stop it.	P찼ralo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111499 (CK) & #4554629 (swyter)
#
# Stop it.	Detenlo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111499 (CK) & #4557336 (swyter)
#
# Take it.	C처gelo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1913089 (CK) & #2292882 (Shishir)
#
# Tell me.	Decime.	CC-BY 2.0 (France) Attribution: tatoeba.org #1913090 (CK) & #1922652 (hayastan)
#
# Tell me.	Cu챕ntame.	CC-BY 2.0 (France) Attribution: tatoeba.org #1913090 (CK) & #6861139 (arh)
#
# Tom ate.	Tom comi처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203599 (CK) & #3346063 (Shishir)
#
# Tom ran.	Tom corri처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203766 (CK) & #3535554 (Aether)
#
# Tom won.	Tom gan처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2005191 (CK) & #2209118 (Shishir)
#
# Wait up.	Esp챕rame despierto.	CC-BY 2.0 (France) Attribution: tatoeba.org #2954108 (CK) & #5769228 (arh)
#
# Wake up!	징Despierta!	CC-BY 2.0 (France) Attribution: tatoeba.org #323780 (CK) & #583494 (Shishir)
#
# Wake up!	징Despi챕rtate!	CC-BY 2.0 (France) Attribution: tatoeba.org #323780 (CK) & #583495 (Shishir)
#
# Wake up!	징Despertate!	CC-BY 2.0 (France) Attribution: tatoeba.org #323780 (CK) & #1335839 (hayastan)
#
# Wake up.	Despierta.	CC-BY 2.0 (France) Attribution: tatoeba.org #1850243 (CK) & #5769221 (arh)
#
# Wash up.	L찼vate las manos.	CC-BY 2.0 (France) Attribution: tatoeba.org #20763 (CK) & #1051757 (Shishir)
#
# We care.	Nos preocupamos.	CC-BY 2.0 (France) Attribution: tatoeba.org #3255558 (CM) & #5769229 (arh)
#
# We know.	Lo sabemos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1556167 (shanghainese) & #5769219 (arh)
#
# We lost.	Perdimos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2107666 (CK) & #5769227 (arh)
#
# Welcome.	Bienvenidos.	CC-BY 2.0 (France) Attribution: tatoeba.org #138919 (CM) & #4587056 (cueyayotl)
#
# Welcome.	Bienvenidas.	CC-BY 2.0 (France) Attribution: tatoeba.org #138919 (CM) & #4587057 (cueyayotl)
#
# Who ate?	쩔Qui챕n comi처?	CC-BY 2.0 (France) Attribution: tatoeba.org #2203598 (CK) & #1446405 (marcelostockle)
#
# Who ran?	쩔Qui챕n corr챠a?	CC-BY 2.0 (France) Attribution: tatoeba.org #2203765 (CK) & #4557668 (swyter)
#
# Who ran?	쩔Qui챕n corri처?	CC-BY 2.0 (France) Attribution: tatoeba.org #2203765 (CK) & #4557669 (swyter)
#
# Who won?	쩔Qui챕n gan처?	CC-BY 2.0 (France) Attribution: tatoeba.org #2005190 (CK) & #4557222 (swyter)
#
# Who won?	쩔Qui챕n ha ganado?	CC-BY 2.0 (France) Attribution: tatoeba.org #2005190 (CK) & #4557225 (swyter)
#
# Why not?	쩔Por qu챕 no?	CC-BY 2.0 (France) Attribution: tatoeba.org #30545 (CK) & #504549 (Shishir)
#
# You run.	Corre.	CC-BY 2.0 (France) Attribution: tatoeba.org #672252 (CK) & #1395910 (marcelostockle)
#
# You won.	Has ganado.	CC-BY 2.0 (France) Attribution: tatoeba.org #2549833 (CK) & #3441812 (Shishir)
#
# Am I fat?	쩔Estoy gordo?	CC-BY 2.0 (France) Attribution: tatoeba.org #2214296 (Hybrid) & #2762301 (Shishir)
#
# Am I fat?	쩔Estoy gorda?	CC-BY 2.0 (France) Attribution: tatoeba.org #2214296 (Hybrid) & #5504681 (ecorralest101)
#
# Ask them.	Preguntales.	CC-BY 2.0 (France) Attribution: tatoeba.org #3820042 (CK) & #5048409 (don_ramon)
#
# Ask them.	Preg첬ntales.	CC-BY 2.0 (France) Attribution: tatoeba.org #3820042 (CK) & #5048411 (don_ramon)
#
# Back off!	Aparta.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954264 (CK) & #5769239 (arh)
#
# Back off.	Ap찼rtate.	CC-BY 2.0 (France) Attribution: tatoeba.org #1553533 (CK) & #1748233 (Shishir)
#
# Be a man.	S챕 un hombre.	CC-BY 2.0 (France) Attribution: tatoeba.org #2221008 (Hybrid) & #4567925 (cueyayotl)
#
# Be brave.	S챕 fuerte.	CC-BY 2.0 (France) Attribution: tatoeba.org #4054941 (CK) & #5707804 (arh)
#
# Be brief.	S챕 breve.	CC-BY 2.0 (France) Attribution: tatoeba.org #3826022 (CK) & #4344850 (pchamorro)
#
# Be brief.	Sea breve.	CC-BY 2.0 (France) Attribution: tatoeba.org #3826022 (CK) & #5048438 (don_ramon)
#
# Be brief.	Sean breves.	CC-BY 2.0 (France) Attribution: tatoeba.org #3826022 (CK) & #5048439 (don_ramon)
#
# Be quiet.	Estate quieto.	CC-BY 2.0 (France) Attribution: tatoeba.org #1275396 (jakov) & #5797129 (arh)
#
# Be still.	No te muevas.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954265 (CK) & #576609 (Shishir)
#
# Call Tom.	징Llamalo a Tom찼s!	CC-BY 2.0 (France) Attribution: tatoeba.org #2203855 (CK) & #5057157 (don_ramon)
#
# Call Tom.	징Ll찼malo a Tom찼s!	CC-BY 2.0 (France) Attribution: tatoeba.org #2203855 (CK) & #5057158 (don_ramon)
#
# Call Tom.	징Ll찼menlo a Tom찼s!	CC-BY 2.0 (France) Attribution: tatoeba.org #2203855 (CK) & #5057159 (don_ramon)
#
# Cheer up!	An챠mate.	CC-BY 2.0 (France) Attribution: tatoeba.org #239441 (CM) & #5769232 (arh)
#
# Cheer up.	Venga.	CC-BY 2.0 (France) Attribution: tatoeba.org #2946394 (alvations) & #5769254 (arh)
#
# Cool off!	징C찼lmate!	CC-BY 2.0 (France) Attribution: tatoeba.org #280162 (CM) & #728700 (ventana)
#
# Cuff him.	Esp처sale.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954267 (CK) & #4557195 (swyter)
#
# Don't go.	No te vayas.	CC-BY 2.0 (France) Attribution: tatoeba.org #773587 (marloncori) & #963095 (hundo)
#
# Drive on.	Contin첬a.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954268 (CK) & #4940109 (Francisco_M)
#
# Find Tom.	Encontralo a Tom찼s.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111838 (CK) & #5048274 (don_ramon)
#
# Find Tom.	Encu챕ntralo a Tom찼s.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111838 (CK) & #5048276 (don_ramon)
#
# Find Tom.	Encu챕ntrelo a Tom찼s.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111838 (CK) & #5048278 (don_ramon)
#
# Find Tom.	Encu챕ntrenlo a Tom찼s.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111838 (CK) & #5048281 (don_ramon)
#
# Find Tom.	Encuentre a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111838 (CK) & #5669438 (arh)
#
# Find Tom.	Encuentren a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111838 (CK) & #5669440 (arh)
#
# Fix this.	Arregla esto.	CC-BY 2.0 (France) Attribution: tatoeba.org #3172185 (CK) & #3389784 (marcelostockle)
#
# Get away!	징Vete de aqu챠!	CC-BY 2.0 (France) Attribution: tatoeba.org #240634 (CM) & #870324 (washisnein)
#
# Get away!	징L찼rgate!	CC-BY 2.0 (France) Attribution: tatoeba.org #240634 (CM) & #877248 (Shishir)
#
# Get away!	징Largo!	CC-BY 2.0 (France) Attribution: tatoeba.org #240634 (CM) & #1266359 (wallebot)
#
# Get away!	징Vete ya!	CC-BY 2.0 (France) Attribution: tatoeba.org #240634 (CM) & #1266363 (wallebot)
#
# Get down!	Ponte a ello.	CC-BY 2.0 (France) Attribution: tatoeba.org #268087 (CM) & #5769234 (arh)
#
# Get down.	Abajo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954269 (CK) & #4557196 (swyter)
#
# Get down.	T첬mbate.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954269 (CK) & #4557197 (swyter)
#
# Get lost!	징Pi챕rdete!	CC-BY 2.0 (France) Attribution: tatoeba.org #623565 (Dorenda) & #623622 (Shishir)
#
# Get lost!	징Vete de aqu챠!	CC-BY 2.0 (France) Attribution: tatoeba.org #623565 (Dorenda) & #870324 (washisnein)
#
# Get lost!	징L찼rgate!	CC-BY 2.0 (France) Attribution: tatoeba.org #623565 (Dorenda) & #877248 (Shishir)
#
# Get lost!	징Largo!	CC-BY 2.0 (France) Attribution: tatoeba.org #623565 (Dorenda) & #1266359 (wallebot)
#
# Get lost!	징Vete ya!	CC-BY 2.0 (France) Attribution: tatoeba.org #623565 (Dorenda) & #1266363 (wallebot)
#
# Get lost.	Esf첬mate.	CC-BY 2.0 (France) Attribution: tatoeba.org #854500 (CK) & #5769237 (arh)
#
# Get real!	징Despierta!	CC-BY 2.0 (France) Attribution: tatoeba.org #326067 (CM) & #583494 (Shishir)
#
# Get real!	징Pi챕nsalo bien!	CC-BY 2.0 (France) Attribution: tatoeba.org #326067 (CM) & #1443713 (marcelostockle)
#
# Get real.	Abre los ojos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1324400 (Scott) & #449333 (Ignatius881)
#
# Go ahead!	Adelante.	CC-BY 2.0 (France) Attribution: tatoeba.org #38590 (CM) & #536647 (Shishir)
#
# Go ahead.	Adelante.	CC-BY 2.0 (France) Attribution: tatoeba.org #38546 (CM) & #536647 (Shishir)
#
# Go on in.	Entre.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954270 (CK) & #1501220 (marcelostockle)
#
# Go on in.	Entra.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954270 (CK) & #2117449 (Shishir)
#
# Go on in.	Entren.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954270 (CK) & #4508612 (cueyayotl)
#
# Go on in.	Entr찼.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954270 (CK) & #4508613 (cueyayotl)
#
# Go on in.	Entrad.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954270 (CK) & #4508614 (cueyayotl)
#
# Going up?	쩔Subes?	CC-BY 2.0 (France) Attribution: tatoeba.org #7163239 (Sleekkat) & #6686526 (arh)
#
# Good job!	징Buen trabajo!	CC-BY 2.0 (France) Attribution: tatoeba.org #1021038 (Quazel) & #1434305 (marcelostockle)
#
# Grab Tom.	Sujeta a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #1972639 (CK) & #2604321 (marcelostockle)
#
# Grab him.	Ag찼rralo.	CC-BY 2.0 (France) Attribution: tatoeba.org #285184 (CK) & #1432374 (marcelostockle)
#
# Have fun.	Divi챕rtanse.	CC-BY 2.0 (France) Attribution: tatoeba.org #21267 (CK) & #5575147 (marcelostockle)
#
# Have fun.	P찼sala bien.	CC-BY 2.0 (France) Attribution: tatoeba.org #21267 (CK) & #5749745 (marcelostockle)
#
# Have fun.	P찼senla bien.	CC-BY 2.0 (France) Attribution: tatoeba.org #21267 (CK) & #5749746 (marcelostockle)
#
# He spoke.	횋l habl처.	CC-BY 2.0 (France) Attribution: tatoeba.org #1564976 (marcelostockle) & #1264086 (Shishir)
#
# He tries.	횋l lo intenta.	CC-BY 2.0 (France) Attribution: tatoeba.org #288166 (CM) & #638131 (Shishir)
#
# He tries.	횋l prueba.	CC-BY 2.0 (France) Attribution: tatoeba.org #288166 (CM) & #638132 (Shishir)
#
# Help Tom.	Ayuda a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203858 (CK) & #4512989 (cueyayotl)
#
# Hi, guys.	Hola, 쩔qu챕 hay?	CC-BY 2.0 (France) Attribution: tatoeba.org #2561375 (Hybrid) & #4557745 (swyter)
#
# Hi, guys.	Ey, chavales.	CC-BY 2.0 (France) Attribution: tatoeba.org #2561375 (Hybrid) & #4557747 (swyter)
#
# Hi, guys.	쩔Qu챕 pasa, troncos?	CC-BY 2.0 (France) Attribution: tatoeba.org #2561375 (Hybrid) & #4557749 (swyter)
#
# Hi, guys.	Buenas.	CC-BY 2.0 (France) Attribution: tatoeba.org #2561375 (Hybrid) & #4557753 (swyter)
#
# Hi, guys.	쩔Qu챕 tal os va?	CC-BY 2.0 (France) Attribution: tatoeba.org #2561375 (Hybrid) & #4557755 (swyter)
#
# Hi, guys.	Hola por aqu챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #2561375 (Hybrid) & #4557756 (swyter)
#
# How cute!	징Qu챕 encanto!	CC-BY 2.0 (France) Attribution: tatoeba.org #36097 (CM) & #512456 (Shishir)
#
# How deep?	쩔Qu챕 tan profundo?	CC-BY 2.0 (France) Attribution: tatoeba.org #37612 (CM) & #1123446 (Ephraim)
#
# How deep?	쩔C처mo de profundo?	CC-BY 2.0 (France) Attribution: tatoeba.org #37612 (CM) & #1480592 (letras_de_aire)
#
# Humor me.	Hazme el favor.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954271 (CM) & #5770446 (swyter)
#
# Humor me.	Compl찼ceme.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954271 (CM) & #5770447 (swyter)
#
# Hurry up.	징Date prisa!	CC-BY 2.0 (France) Attribution: tatoeba.org #1329 (brauliobezerra) & #2535 (Shishir)
#
# Hurry up.	Apres첬rate.	CC-BY 2.0 (France) Attribution: tatoeba.org #1329 (brauliobezerra) & #1173024 (marcelostockle)
#
# Hurry up.	Ap첬rese.	CC-BY 2.0 (France) Attribution: tatoeba.org #1329 (brauliobezerra) & #5024609 (don_ramon)
#
# I agreed.	Convine.	CC-BY 2.0 (France) Attribution: tatoeba.org #2455128 (CK) & #4557722 (swyter)
#
# I agreed.	Acept챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #2455128 (CK) & #4557726 (swyter)
#
# I agreed.	Acced챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #2455128 (CK) & #4557728 (swyter)
#
# I am old.	Estoy viejo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1547545 (CM) & #1705592 (marcelostockle)
#
# I ate it.	Me lo com챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #2332094 (Sharaf78) & #2333094 (marcelostockle)
#
# I ate it.	Me la com챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #2332094 (Sharaf78) & #4505636 (cueyayotl)
#
# I can go.	Puedo ir.	CC-BY 2.0 (France) Attribution: tatoeba.org #3092548 (CK) & #4521968 (cueyayotl)
#
# I cursed.	Maldije.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397701 (CK) & #8410520 (arh)
#
# I cursed.	Despotriqu챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #8397701 (CK) & #8410521 (arh)
#
# I did OK.	Lo hice bien.	CC-BY 2.0 (France) Attribution: tatoeba.org #4498134 (CK) & #5769259 (arh)
#
# I did it.	Lo hice.	CC-BY 2.0 (France) Attribution: tatoeba.org #2549832 (CK) & #2625373 (Shishir)
#
# I failed.	Fracas챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #2484985 (AlanF_US) & #4986965 (cueyayotl)
#
# I forgot.	Lo olvid챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #436603 (lukaszpp) & #1582696 (Alba)
#
# I get by.	Me las arreglo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2476830 (arnxy20) & #5769253 (arh)
#
# I get it.	Lo entiendo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1691393 (aka_aj) & #576615 (Shishir)
#
# I got it.	Lo tengo.	CC-BY 2.0 (France) Attribution: tatoeba.org #433472 (CK) & #5769236 (arh)
#
# I jumped.	Salt챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828631 (CK) & #7634519 (arh)
#
# I phoned.	Llam챕 por tel챕fono.	CC-BY 2.0 (France) Attribution: tatoeba.org #1357258 (sacredceltic) & #4526795 (cueyayotl)
#
# I refuse.	Me niego.	CC-BY 2.0 (France) Attribution: tatoeba.org #3930181 (Youmu970) & #5669425 (arh)
#
# I resign.	Dimito.	CC-BY 2.0 (France) Attribution: tatoeba.org #731590 (Eldad) & #731631 (Shishir)
#
# I resign.	Renuncio.	CC-BY 2.0 (France) Attribution: tatoeba.org #731590 (Eldad) & #731632 (Shishir)
#
# I sat up.	Me sent챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #7538189 (CK) & #6683741 (arh)
#
# I saw it.	Lo vi.	CC-BY 2.0 (France) Attribution: tatoeba.org #2247397 (CK) & #531463 (Shishir)
#
# I sighed.	Suspir챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #7538191 (CK) & #7623643 (arh)
#
# I smiled.	Sonre챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #3651941 (Luciosp) & #5147460 (Kary)
#
# I stayed.	Me qued챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #2123630 (CK) & #4557571 (swyter)
#
# I talked.	Habl챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828639 (CK) & #6686448 (arh)
#
# I talked.	Hablaba.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828639 (CK) & #6686449 (arh)
#
# I talked.	Charl챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828639 (CK) & #6686452 (arh)
#
# I talked.	Charlaba.	CC-BY 2.0 (France) Attribution: tatoeba.org #5828639 (CK) & #6686453 (arh)
#
# I use it.	Yo lo uso.	CC-BY 2.0 (France) Attribution: tatoeba.org #254813 (CK) & #1443714 (marcelostockle)
#
# I waited.	Esper챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #2123628 (CK) & #5769243 (arh)
#
# I'll pay.	Yo pagar챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #411285 (CK) & #615668 (Leono)
#
# I'm back.	He vuelto.	CC-BY 2.0 (France) Attribution: tatoeba.org #564159 (darinmex) & #591718 (Shishir)
#
# I'm back.	Estoy de vuelta.	CC-BY 2.0 (France) Attribution: tatoeba.org #564159 (darinmex) & #1549494 (cueyayotl)
#
# I'm bald.	Soy calvo.	CC-BY 2.0 (France) Attribution: tatoeba.org #3330667 (CK) & #3410159 (gianich73)
#
# I'm bald.	Estoy calvo.	CC-BY 2.0 (France) Attribution: tatoeba.org #3330667 (CK) & #3562758 (ficion)
#
# I'm calm.	Estoy calmado.	CC-BY 2.0 (France) Attribution: tatoeba.org #2948173 (Joseph) & #5769255 (arh)
#
# I'm cool.	Estoy tranquilo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202692 (CK) & #5797130 (arh)
#
# I'm done.	He terminado.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202792 (CK) & #4637891 (Francisco_M)
#
# I'm done.	Estoy acabado.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202792 (CK) & #7551140 (arh)
#
# I'm done.	Lo dejo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202792 (CK) & #7578166 (arh)
#
# I'm easy.	Soy bastante facil처n.	CC-BY 2.0 (France) Attribution: tatoeba.org #255173 (CK) & #4557835 (swyter)
#
# I'm fair.	Soy justo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202832 (CK) & #5769246 (arh)
#
# I'm fine.	Estoy perfectamente.	CC-BY 2.0 (France) Attribution: tatoeba.org #257272 (Eldad) & #5769233 (arh)
#
# I'm free!	징Soy libre!	CC-BY 2.0 (France) Attribution: tatoeba.org #1888443 (Spamster) & #1888674 (hayastan)
#
# I'm free.	Yo soy libre.	CC-BY 2.0 (France) Attribution: tatoeba.org #23959 (CK) & #977447 (hayastan)
#
# I'm full.	Estoy lleno.	CC-BY 2.0 (France) Attribution: tatoeba.org #433863 (CK) & #520784 (Shishir)
#
# I'm full.	Estoy llena.	CC-BY 2.0 (France) Attribution: tatoeba.org #433863 (CK) & #520789 (Shishir)
#
# I'm full.	Ya me llen챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #433863 (CK) & #5101739 (ecorralest101)
#
# I'm here.	Estoy aqu챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111726 (CK) & #2005522 (Shishir)
#
# I'm home.	Estoy en casa.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111725 (CK) & #1013884 (hayastan)
#
# I'm hurt.	Estoy herido.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111723 (CK) & #2566031 (hayastan)
#
# I'm late.	Llego tarde.	CC-BY 2.0 (France) Attribution: tatoeba.org #2123622 (CK) & #5769242 (arh)
#
# I'm lazy.	Soy vago.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203056 (CK) & #5769247 (arh)
#
# I'm lost.	Estoy perdida.	CC-BY 2.0 (France) Attribution: tatoeba.org #455833 (lukaszpp) & #1173683 (Shishir)
#
# I'm mean.	Soy malo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203077 (CK) & #5769248 (arh)
#
# I'm next.	Me toca a m챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #3171892 (CK) & #5769256 (arh)
#
# I'm okay.	Estoy perfectamente.	CC-BY 2.0 (France) Attribution: tatoeba.org #2283729 (CK) & #5769233 (arh)
#
# I'm poor.	Soy pobre.	CC-BY 2.0 (France) Attribution: tatoeba.org #261477 (CK) & #454613 (Shishir)
#
# I'm rich.	Soy rica.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203289 (CK) & #2914133 (hayastan)
#
# I'm rich.	Soy rico.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203289 (CK) & #2914134 (hayastan)
#
# I'm safe.	Estoy a salvo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203309 (CK) & #5769249 (arh)
#
# I'm sick.	Estoy enferma.	CC-BY 2.0 (France) Attribution: tatoeba.org #780304 (vgigregg) & #1989704 (Shishir)
#
# I'm thin.	Soy delgado.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203445 (CK) & #5769250 (arh)
#
# I'm tidy.	Estoy limpio.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203456 (CK) & #5769251 (arh)
#
# I'm warm.	Estoy calentito.	CC-BY 2.0 (France) Attribution: tatoeba.org #2713786 (CK) & #5797131 (arh)
#
# I'm weak.	Estoy d챕bil.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203572 (CK) & #5057214 (don_ramon)
#
# I'm wise.	Soy listo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203582 (CK) & #2094591 (Shishir)
#
# I've won.	Gan챕.	CC-BY 2.0 (France) Attribution: tatoeba.org #2283734 (CK) & #3232049 (Shishir)
#
# It helps.	Eso ayuda.	CC-BY 2.0 (France) Attribution: tatoeba.org #2123616 (CK) & #4512986 (cueyayotl)
#
# It hurts.	Duele.	CC-BY 2.0 (France) Attribution: tatoeba.org #2649251 (CK) & #3215656 (marcelostockle)
#
# It works.	Funciona.	CC-BY 2.0 (France) Attribution: tatoeba.org #1365269 (sacredceltic) & #5769238 (arh)
#
# It's Tom.	Es Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2123573 (CK) & #2150024 (hayastan)
#
# It's fun.	Es divertido.	CC-BY 2.0 (France) Attribution: tatoeba.org #2123602 (CK) & #2127374 (Shishir)
#
# It's his.	Es suyo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2187229 (CK) & #5769245 (arh)
#
# It's new.	Es nuevo.	CC-BY 2.0 (France) Attribution: tatoeba.org #42304 (CK) & #866287 (jorgearestrepo)
#
# It's odd.	Es extra챰o.	CC-BY 2.0 (France) Attribution: tatoeba.org #2283742 (CK) & #1248522 (Shishir)
#
# It's old.	Es viejo.	CC-BY 2.0 (France) Attribution: tatoeba.org #3821793 (CK) & #2353306 (Shishir)
#
# It's red.	Es rojo.	CC-BY 2.0 (France) Attribution: tatoeba.org #3821226 (CK) & #5769257 (arh)
#
# It's sad.	Es triste.	CC-BY 2.0 (France) Attribution: tatoeba.org #2515077 (CK) & #5583964 (baudelaire)
#
# Keep out!	Prohibido pasar.	CC-BY 2.0 (France) Attribution: tatoeba.org #325436 (CK) & #1661847 (marcelostockle)
#
# Keep out.	No entrar.	CC-BY 2.0 (France) Attribution: tatoeba.org #325435 (CK) & #1181003 (marcelostockle)
#
# Kiss Tom.	Bes찼 a Tom찼s.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203863 (CK) & #5056304 (don_ramon)
#
# Kiss Tom.	Besa a Tom찼s.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203863 (CK) & #5056306 (don_ramon)
#
# Kiss Tom.	Besen a Tom찼s.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203863 (CK) & #5056308 (don_ramon)
#
# Leave it.	D챕jalo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954272 (CK) & #1054411 (Shishir)
#
# Leave me.	D챕jame.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954273 (CK) & #3338527 (Shishir)
#
# Leave us.	D챕janos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954274 (CK) & #4557198 (swyter)
#
# Let's go!	V찼monos.	CC-BY 2.0 (France) Attribution: tatoeba.org #241077 (CK) & #627825 (Shishir)
#
# Let's go!	Vamos.	CC-BY 2.0 (France) Attribution: tatoeba.org #241077 (CK) & #790255 (chinopinyin)
#
# Let's go!	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #241077 (CK) & #4726230 (cueyayotl)
#
# Let's go.	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #1894538 (CK) & #4726230 (cueyayotl)
#
# Look out!	Cuidado.	CC-BY 2.0 (France) Attribution: tatoeba.org #20719 (CK) & #5769231 (arh)
#
# Marry me.	C찼sate conmigo.	CC-BY 2.0 (France) Attribution: tatoeba.org #1954275 (CK) & #4557199 (swyter)
#
# May I go?	쩔Puedo ir?	CC-BY 2.0 (France) Attribution: tatoeba.org #2163138 (Source_VOA) & #5769244 (arh)
#
# Save Tom.	Salva a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203865 (CK) & #5752503 (arh)
#
# She came.	Ella vino.	CC-BY 2.0 (France) Attribution: tatoeba.org #853152 (piksea) & #853496 (japegon)
#
# She died.	Ella muri처.	CC-BY 2.0 (France) Attribution: tatoeba.org #1400268 (enteka) & #1400124 (hayastan)
#
# She runs.	Ella corre.	CC-BY 2.0 (France) Attribution: tatoeba.org #672264 (CM) & #870264 (inmachan)
#
# Sit down!	징Sentate!	CC-BY 2.0 (France) Attribution: tatoeba.org #1349166 (sacredceltic) & #2442797 (hayastan)
#
# Sit down.	Si챕ntate.	CC-BY 2.0 (France) Attribution: tatoeba.org #1553397 (CK) & #2098372 (Shishir)
#
# Sit down.	Sentate.	CC-BY 2.0 (France) Attribution: tatoeba.org #1553397 (CK) & #2973538 (hayastan)
#
# Sit here.	Si챕ntate aqu챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111553 (CK) & #3761301 (cueyayotl)
#
# Speak up!	징Hable m찼s fuerte!	CC-BY 2.0 (France) Attribution: tatoeba.org #35175 (CK) & #683388 (humbertovs)
#
# Speak up!	Habla m찼s fuerte.	CC-BY 2.0 (France) Attribution: tatoeba.org #35175 (CK) & #941229 (hayastan)
#
# Speak up!	징Habla m찼s alto!	CC-BY 2.0 (France) Attribution: tatoeba.org #35175 (CK) & #1240442 (Shishir)
#
# Stand by.	Prep찼rate.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111528 (CK) & #730482 (chinopinyin)
#
# Stand by.	Un momento.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111528 (CK) & #4554561 (swyter)
#
# Stand up!	징Parate!	CC-BY 2.0 (France) Attribution: tatoeba.org #325429 (CK) & #1314246 (hayastan)
#
# Stand up!	징De pie!	CC-BY 2.0 (France) Attribution: tatoeba.org #325429 (CK) & #1390118 (wallebot)
#
# Stay put.	No te muevas.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111511 (CK) & #576609 (Shishir)
#
# Stop Tom.	Det챕n a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203866 (CK) & #5752504 (arh)
#
# Take Tom.	Ll챕vate a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111478 (CK) & #4557310 (swyter)
#
# Tell Tom.	D챠selo a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111475 (CK) & #4557308 (swyter)
#
# Terrific!	징Genial!	CC-BY 2.0 (France) Attribution: tatoeba.org #52022 (Zifre) & #855587 (sharin)
#
# Terrific!	징횙rale!	CC-BY 2.0 (France) Attribution: tatoeba.org #52022 (Zifre) & #4726230 (cueyayotl)
#
# They won.	Ellos ganaron.	CC-BY 2.0 (France) Attribution: tatoeba.org #1618734 (CK) & #1705511 (teskmon)
#
# Tom came.	Tom vino.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203606 (CK) & #4527891 (cueyayotl)
#
# Tom died.	Tom ha muerto.	CC-BY 2.0 (France) Attribution: tatoeba.org #2005188 (CK) & #2353267 (Shishir)
#
# Tom fell.	Tom se cay처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203679 (CK) & #1410209 (marcelostockle)
#
# Tom knew.	Tom lo sab챠a.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203721 (CK) & #4526223 (Shishir)
#
# Tom knew.	Tom ten챠a constancia de ello.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203721 (CK) & #4557653 (swyter)
#
# Tom left.	Tom se fue.	CC-BY 2.0 (France) Attribution: tatoeba.org #2005178 (CK) & #4527536 (cueyayotl)
#
# Tom lied.	Tom minti처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2005179 (CK) & #3143021 (cueyayotl)
#
# Tom lies.	Tom찼s miente.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203722 (CK) & #5137741 (don_ramon)
#
# Tom lost.	Tom perdi처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2005180 (CK) & #4527537 (cueyayotl)
#
# Tom paid.	Tom pag처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2111155 (CK) & #4527551 (cueyayotl)
#
# Tom quit.	Tom renunci처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2005183 (CK) & #4527543 (cueyayotl)
#
# Tom swam.	Tom nad처.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203845 (CK) & #4997892 (cueyayotl)
#
# Tom wept.	Tom llor처.	CC-BY 2.0 (France) Attribution: tatoeba.org #1524763 (Spamster) & #1713564 (marcelostockle)
#
# Tom's up.	Tom se ha levantado.	CC-BY 2.0 (France) Attribution: tatoeba.org #2107644 (CK) & #5752502 (arh)
#
# Too late.	Demasiado tarde.	CC-BY 2.0 (France) Attribution: tatoeba.org #1875 (Swift) & #2946 (Shishir)
#
# ...
#
# Watch carefully.	Mira cuidadosamente.	CC-BY 2.0 (France) Attribution: tatoeba.org #2107662 (CK) & #5047992 (don_ramon)
#
# Watch carefully.	Mir찼 cuidadosamente.	CC-BY 2.0 (France) Attribution: tatoeba.org #2107662 (CK) & #5047996 (don_ramon)
#
# Watch your step.	Mira por d처nde caminas.	CC-BY 2.0 (France) Attribution: tatoeba.org #274491 (CK) & #1284322 (marcelostockle)
#
# Watch your toes.	Cuidado con los dedos de los pies.	CC-BY 2.0 (France) Attribution: tatoeba.org #274479 (CK) & #4557883 (swyter)
#
# We all hate you.	Todos te odiamos.	CC-BY 2.0 (France) Attribution: tatoeba.org #3915694 (CK) & #4225014 (hayastan)
#
# We all like him.	A todos nos agrada 챕l.	CC-BY 2.0 (France) Attribution: tatoeba.org #262866 (CK) & #1284323 (marcelostockle)
#
# We all love Tom.	Todos amamos a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2549440 (CK) & #3366984 (cueyayotl)
#
# We are brothers.	Somos hermanos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1439471 (CK) & #1439470 (Shishir)
#
# We are his sons.	Nosotros somos sus hijos.	CC-BY 2.0 (France) Attribution: tatoeba.org #247784 (CK) & #1022387 (hayastan)
#
# We are teachers.	Somos profesores.	CC-BY 2.0 (France) Attribution: tatoeba.org #263111 (CK) & #977088 (Shishir)
#
# We are teachers.	Somos maestros.	CC-BY 2.0 (France) Attribution: tatoeba.org #263111 (CK) & #977089 (Shishir)
#
# We aren't alone.	No estamos solos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893935 (CK) & #2136828 (Shishir)
#
# We aren't alone.	No estamos solas.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893935 (CK) & #2136830 (Shishir)
#
# We arrested Tom.	Arrestamos a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240288 (CK) & #2592842 (hayastan)
#
# We ate together.	Comimos juntos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2342560 (Hybrid) & #2342965 (marcelostockle)
#
# We both laughed.	Los dos nos re챠mos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1866432 (Spamster) & #1868677 (Shishir)
#
# We both laughed.	Las dos nos re챠mos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1866432 (Spamster) & #1868678 (Shishir)
#
# We can help Tom.	Podemos ayudar a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893928 (CK) & #1998640 (Shishir)
#
# We can help you.	Podemos ayudarte.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893927 (CK) & #1893987 (Shishir)
#
# We can help you.	Podemos ayudarlos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893927 (CK) & #5017137 (don_ramon)
#
# We can pay cash.	Nosotros podemos pagar en met찼lico.	CC-BY 2.0 (France) Attribution: tatoeba.org #4397517 (CK) & #5952639 (albrusgher)
#
# We closed early.	Cerramos temprano.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241055 (CK) & #4960783 (albrusgher)
#
# We count on you.	Contamos con ustedes.	CC-BY 2.0 (France) Attribution: tatoeba.org #1388963 (CK) & #1388936 (hayastan)
#
# We didn't do it.	Nosotros no lo hicimos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2273827 (CK) & #2878264 (teskmon)
#
# We eat fish raw.	Comemos pescado crudo.	CC-BY 2.0 (France) Attribution: tatoeba.org #23047 (Swift) & #855591 (sharin)
#
# We have a guest.	Tenemos visita.	CC-BY 2.0 (France) Attribution: tatoeba.org #3527258 (adamtrousers) & #5575159 (marcelostockle)
#
# We have no time.	No tenemos tiempo.	CC-BY 2.0 (France) Attribution: tatoeba.org #31348 (sysko) & #534183 (Shishir)
#
# We have nothing.	No tenemos nada.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241110 (CK) & #3231933 (Shishir)
#
# We lack nothing.	No nos falta de nada.	CC-BY 2.0 (France) Attribution: tatoeba.org #248471 (CK) & #1798794 (Shishir)
#
# We lack nothing.	No nos falta nada.	CC-BY 2.0 (France) Attribution: tatoeba.org #248471 (CK) & #1798795 (Shishir)
#
# We left at 2:30.	Salimos a las dos y media.	CC-BY 2.0 (France) Attribution: tatoeba.org #4755080 (CK) & #5769266 (arh)
#
# We like to talk.	Nos gusta conversar.	CC-BY 2.0 (France) Attribution: tatoeba.org #1529246 (erikspen) & #2783491 (marcelostockle)
#
# We love it here.	Nos encanta esta zona.	CC-BY 2.0 (France) Attribution: tatoeba.org #4500895 (CK) & #4774635 (alegarvid)
#
# We love it here.	Nos encanta estar aqu챠.	CC-BY 2.0 (France) Attribution: tatoeba.org #4500895 (CK) & #4774636 (alegarvid)
#
# We love picnics.	Nos encantan los picnics.	CC-BY 2.0 (France) Attribution: tatoeba.org #956923 (CK) & #1360645 (Shishir)
#
# We made him cry.	Le hicimos llorar.	CC-BY 2.0 (France) Attribution: tatoeba.org #263236 (CK) & #623917 (clerval)
#
# We made waffles.	Hicimos waffles.	CC-BY 2.0 (France) Attribution: tatoeba.org #1683806 (Spamster) & #1683814 (marcelostockle)
#
# We made waffles.	Hicimos gofres.	CC-BY 2.0 (France) Attribution: tatoeba.org #1683806 (Spamster) & #1686312 (Shishir)
#
# We met a writer.	Conocimos un escritor.	CC-BY 2.0 (France) Attribution: tatoeba.org #370544 (saeb) & #1355623 (marcelostockle)
#
# We ought to win.	Deber챠amos ganar.	CC-BY 2.0 (France) Attribution: tatoeba.org #22912 (CK) & #538622 (Shishir)
#
# We pay Tom well.	Le pagamos bien a Tom.	CC-BY 2.0 (France) Attribution: tatoeba.org #2856416 (Amastan) & #5952280 (albrusgher)
#
# We sang for her.	Nosotros cantamos para ella.	CC-BY 2.0 (France) Attribution: tatoeba.org #263247 (CK) & #1284324 (marcelostockle)
#
# We shared ideas.	Compartimos ideas.	CC-BY 2.0 (France) Attribution: tatoeba.org #4502073 (CK) & #5130923 (don_ramon)
#
# We should leave.	Deber챠amos irnos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1488836 (arnxy20) & #1526275 (marcelostockle)
#
# We speak French.	Hablamos franc챕s.	CC-BY 2.0 (France) Attribution: tatoeba.org #4667249 (CK) & #5755798 (arh)
#
# We study French.	Estudiamos franc챕s.	CC-BY 2.0 (France) Attribution: tatoeba.org #2451685 (CK) & #2454415 (hayastan)
#
# We walked a lot.	Andamos mucho.	CC-BY 2.0 (France) Attribution: tatoeba.org #2084 (Swift) & #460391 (Shishir)
#
# We want it back.	Lo queremos de vuelta.	CC-BY 2.0 (France) Attribution: tatoeba.org #2549430 (CK) & #2747287 (hantol01)
#
# We want justice.	Queremos justicia.	CC-BY 2.0 (France) Attribution: tatoeba.org #1869775 (Spamster) & #2098374 (Shishir)
#
# We want to help.	Queremos ayudar.	CC-BY 2.0 (France) Attribution: tatoeba.org #2011325 (CK) & #2169637 (hayastan)
#
# We want to know.	Queremos saber.	CC-BY 2.0 (France) Attribution: tatoeba.org #2011326 (CK) & #2169636 (hayastan)
#
# We want to talk.	Queremos hablar.	CC-BY 2.0 (France) Attribution: tatoeba.org #2011327 (CK) & #2169635 (hayastan)
#
# We want to vote.	Queremos votar.	CC-BY 2.0 (France) Attribution: tatoeba.org #2011328 (CK) & #2166456 (hayastan)
#
# We were friends.	횋ramos amigos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1553332 (CK) & #1556057 (hayastan)
#
# We were talking.	Est찼bamos hablando.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241510 (CK) & #3520348 (Aether)
#
# We were worried.	Est찼bamos preocupados.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893678 (CK) & #2114008 (Shishir)
#
# We'll be killed.	Seremos asesinados.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241544 (CK) & #4793892 (DarkHollow)
#
# We'll know soon.	Pronto lo vamos a saber.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241600 (CK) & #2422208 (hayastan)
#
# We'll stay here.	Nos vamos a quedar ac찼.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241622 (CK) & #2422206 (hayastan)
#
# We'll stop them.	Los detendremos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241626 (CK) & #3528715 (Aether)
#
# We'll visit you.	Te visitaremos.	CC-BY 2.0 (France) Attribution: tatoeba.org #4493318 (AlanF_US) & #3135521 (marcelostockle)
#
# We'll wait here.	Vamos a esperar ac찼.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241639 (CK) & #2449250 (hayastan)
#
# We're Canadians.	Somos canadienses.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202636 (CK) & #2673368 (Shishir)
#
# We're all dying.	Nos estamos muriendo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240826 (CK) & #2251851 (Shishir)
#
# We're all dying.	Nos estamos muriendo todos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240826 (CK) & #5566445 (swyter)
#
# We're all happy.	Todos nosotros somos felices.	CC-BY 2.0 (France) Attribution: tatoeba.org #931430 (Shiawase) & #1490423 (marcelostockle)
#
# We're all tired.	Estamos todos cansados.	CC-BY 2.0 (France) Attribution: tatoeba.org #4502663 (CK) & #4545880 (DarkHollow)
#
# We're available.	Estamos disponibles.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202595 (CK) & #3148206 (leoruilova)
#
# We're both fine.	Los dos estamos bien.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893654 (CK) & #2688476 (Shishir)
#
# We're both rich.	Los dos somos ricos.	CC-BY 2.0 (France) Attribution: tatoeba.org #4967670 (CK) & #4968019 (Shishir)
#
# We're confident.	Estamos seguros.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202672 (CK) & #4375701 (pchamorro)
#
# We're easygoing.	Somos simp찼ticos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202795 (CK) & #6603015 (arh)
#
# We're easygoing.	Somos cordiales.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202795 (CK) & #6603018 (arh)
#
# We're exhausted.	Estamos fundidos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202817 (CK) & #5022410 (don_ramon)
#
# We're going out.	Vamos a salir.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240583 (CK) & #6614104 (arh)
#
# We're going out.	Nosotros salimos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240583 (CK) & #6614105 (arh)
#
# We're impartial.	Somos imparciales.	CC-BY 2.0 (France) Attribution: tatoeba.org #2202973 (CK) & #6603037 (arh)
#
# We're in Boston.	Estamos en Boston.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240762 (CK) & #2423900 (hayastan)
#
# We're in charge.	Estamos a cargo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240591 (CK) & #2423939 (hayastan)
#
# We're in danger.	Estamos en peligro.	CC-BY 2.0 (France) Attribution: tatoeba.org #1651930 (Spamster) & #1654879 (Alba)
#
# We're intrigued.	Estamos intrigados.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203030 (CK) & #2828881 (marcelostockle)
#
# We're listening.	Estamos escuchando.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893640 (CK) & #2711424 (Shishir)
#
# We're losing it.	Le estamos perdiendo.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240607 (CK) & #3115466 (Darukeru)
#
# We're newlyweds.	Somos reci챕n casados.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893639 (CK) & #6602996 (arh)
#
# We're newlyweds.	Estamos reci챕n casados.	CC-BY 2.0 (France) Attribution: tatoeba.org #1893639 (CK) & #6602997 (arh)
#
# We're not alone.	No estamos solos.	CC-BY 2.0 (France) Attribution: tatoeba.org #1806067 (CK) & #2136828 (Shishir)
#
# We're not alone.	No estamos solas.	CC-BY 2.0 (France) Attribution: tatoeba.org #1806067 (CK) & #2136830 (Shishir)
#
# We're not crazy.	No estamos locos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240615 (CK) & #2675872 (Shishir)
#
# We're not crazy.	No estamos locas.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240615 (CK) & #2675874 (Shishir)
#
# We're not going.	Nosotros no vamos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240619 (CK) & #6614108 (arh)
#
# We're not going.	No vamos a ir.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240619 (CK) & #6614109 (arh)
#
# We're not ready.	No estamos listos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240635 (CK) & #2423933 (hayastan)
#
# We're objective.	Somos objetivos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203121 (CK) & #3512883 (Aether)
#
# We're organized.	Estamos organizados.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203145 (CK) & #2248534 (marcelostockle)
#
# We're prisoners.	Somos prisioneros.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203756 (CK) & #5000974 (DarkHollow)
#
# We're satisfied.	Estamos satisfechos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2203316 (CK) & #5566784 (swyter)
#
# We're separated.	Estamos separados.	CC-BY 2.0 (France) Attribution: tatoeba.org #2107358 (CK) & #2580802 (hayastan)
#
# We're too close.	Estamos demasiado cerca.	CC-BY 2.0 (France) Attribution: tatoeba.org #2240675 (CK) & #4960785 (albrusgher)
#
# We're too drunk.	Estamos demasiado borrachos.	CC-BY 2.0 (France) Attribution: tatoeba.org #6874267 (CK) & #6874952 (arh)
#
# We're too drunk.	Estamos demasiado bebidos.	CC-BY 2.0 (France) Attribution: tatoeba.org #6874267 (CK) & #6874953 (arh)
#
# We've been away.	Hemos estado lejos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241652 (CK) & #2710986 (caiser)
#
# We've come home.	Hemos venido a casa.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241668 (CK) & #2711003 (caiser)
#
# We've done that.	Hemos hecho eso.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241671 (CK) & #2711008 (caiser)
#
# We've got these.	Tenemos esos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241681 (CK) & #2711025 (caiser)
#
# We've got to go.	Deber챠amos irnos.	CC-BY 2.0 (France) Attribution: tatoeba.org #3310186 (CK) & #1526275 (marcelostockle)
#
# We've lost them.	Los perdimos.	CC-BY 2.0 (France) Attribution: tatoeba.org #2254492 (CK) & #3943614 (cueyayotl)
#
# We've seen them.	Los hemos visto.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241698 (CK) & #2613386 (Shishir)
#
# We've seen them.	Las hemos visto.	CC-BY 2.0 (France) Attribution: tatoeba.org #2241698 (CK) & #2613387 (Shishir)
#
# Well done, guys.	Bravo, amigos m챠os.	CC-BY 2.0 (France) Attribution: tatoeba.org #2000268 (CK) & #2427574 (Shishir)
#
# Were you crying?	쩔Estabas llorando?	CC-BY 2.0 (France) Attribution: tatoeba.org #1866426 (Spamster) & #1868672 (Shishir)
#
# Were you crying?	쩔Estabais llorando?	CC-BY 2.0 (France) Attribution: tatoeba.org #1866426 (Spamster) & #1868674 (Shishir)
#
# What a disaster!	징Qu챕 desastre!	CC-BY 2.0 (France) Attribution: tatoeba.org #2254526 (CK) & #1744901 (Shishir)
#
# What a disaster!	징Qu챕 cat찼strofe!	CC-BY 2.0 (France) Attribution: tatoeba.org #2254526 (CK) & #1804020 (marcelostockle)
#
# What a huge dog!	징Qu챕 perro m찼s grande!	CC-BY 2.0 (France) Attribution: tatoeba.org #572577 (fliegster) & #1236829 (Shishir)
#
# What a huge dog!	징Pero qu챕 enorme perro!	CC-BY 2.0 (France) Attribution: tatoeba.org #572577 (fliegster) & #1241416 (marcelostockle)
#
# What a rude man!	징Qu챕 tipo grosero!	CC-BY 2.0 (France) Attribution: tatoeba.org #36083 (CM) & #1630817 (hayastan)
#
# What a surprise!	징Qu챕 sorpresa!	CC-BY 2.0 (France) Attribution: tatoeba.org #18893 (CK) & #599606 (Shishir)
#
# What can you do?	쩔Qu챕 puedes hacer?	CC-BY 2.0 (France) Attribution: tatoeba.org #1476455 (Spamster) & #2019568 (Shishir)
#
# What comes next?	쩔Qu챕 sigue despu챕s?	CC-BY 2.0 (France) Attribution: tatoeba.org #2254551 (CK) & #4317932 (pchamorro)
#
# What comes next?	쩔Qu챕 sigue a continuaci처n?	CC-BY 2.0 (France) Attribution: tatoeba.org #2254551 (CK) & #4317933 (pchamorro)
#
# What could I do?	쩔Qu챕 podr챠a hacer?	CC-BY 2.0 (France) Attribution: tatoeba.org #2561173 (Hybrid) & #7551141 (arh)
#
# What did I miss?	쩔Qu챕 me perd챠?	CC-BY 2.0 (France) Attribution: tatoeba.org #1841547 (CK) & #2525134 (marcelostockle)
#
# What did Tom do?	쩔Qu챕 hizo Tom?	CC-BY 2.0 (France) Attribution: tatoeba.org #1886792 (CK) & #2019565 (Shishir)
#
# What did he say?	쩔Qu챕 dijo?	CC-BY 2.0 (France) Attribution: tatoeba.org #28006 (CK) & #900654 (felipeselles)
# What did you do?	쩔Qu챕 hiciste?	CC-BY 2.0 (France) Attribution: tatoeba.org #1495903 (CK) & #738720 (chinopinyin)
#
# What do they do?	쩔Qu챕 hacen ellos?	CC-BY 2.0 (France) Attribution: tatoeba.org #2648892 (CK) & #2787464 (marcelostockle)
#
# What is missing?	쩔Qu챕 falta?	CC-BY 2.0 (France) Attribution: tatoeba.org #25227 (CK) & #519499 (Shishir)
#
# What killed Tom?	쩔Qu챕 mat처 a Tom?	CC-BY 2.0 (France) Attribution: tatoeba.org #1886723 (CK) & #2378423 (Shishir)
#
# What time is it?	쩔Qu챕 hora es?	CC-BY 2.0 (France) Attribution: tatoeba.org #428402 (laofmoonster) & #2830 (Shishir)
#
# What was stolen?	쩔Qu챕 fue robado?	CC-BY 2.0 (France) Attribution: tatoeba.org #24678 (CK) & #1284325 (marcelostockle)
#
# What year is it?	쩔Qu챕 a챰o es?	CC-BY 2.0 (France) Attribution: tatoeba.org #682508 (Source_VOA) & #1284326 (marcelostockle)
#
# What year is it?	쩔En qu챕 a챰o estamos?	CC-BY 2.0 (France) Attribution: tatoeba.org #682508 (Source_VOA) & #1294965 (hayastan)
#
# What's Tom like?	쩔C처mo es Tom?	CC-BY 2.0 (France) Attribution: tatoeba.org #1040481 (CK) & #1286260 (marcelostockle)
#
# What's at stake?	쩔Qu챕 est찼 en peligro?	CC-BY 2.0 (France) Attribution: tatoeba.org #2234064 (CK) & #5863997 (albrusgher)
#
# num samples: 10000
